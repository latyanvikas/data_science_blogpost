# %% [markdown]
# # Programming languages usage & salary trend between Men and Women in India
#
# ## 1. Business Understanding
#
#
# For this project, I was interestested in using Stack Overflow data from 2018-2020 to answer the following questions
#
# <ul>
# <li>Most popular languages in india across years?</li>
# <li>Which is the most lucrative programming languages people want to puruse in India?</li>
# <li>How do men and women differ in terms of choice of popular languages being used in India as per 2020 respondents?</li>
# <li>Finally, the salary comparison between Men and Women in India?</li>
# </ul>

# %%
#Importing the packages and setting display setting

import numpy as np
import pandas as pd

# to plot grpahs
import matplotlib.pyplot as plt
import seaborn as sns
import collections
# %matplotlib inline

#set the display size

pd.pandas.set_option('display.max_columns', None)

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# #Checking the current working directory

# %%
#know your current working directory

import os
os.getcwd()
# Out:
# 'D:\\ds\\code\\data_science_blogpost'

# %% [markdown]
# ## 2. Data Understanding
#
# We reading the last 3 years data from stackoverflow. In order to answer our business questions, we will be using the following fields.
#
# <ol>
# <li>Country - To subset the repondents from India</li>
# <li>LanguageWorkedWith - To understand what are the different language people are working with</li>
# <li>LanguageDesireNextYear - What people want to learn next year</li>
# <li>Gender - gender of the repondents</li>
# <li>ConvertedComp - Compensation</li>
# </ol>

# %%
# read the survey data downloaded from stackoverflow

df_2018 = pd.read_csv('data/survey_results_public_2018.csv')
df_2019 = pd.read_csv('data/survey_results_public_2019.csv')
df_2020 = pd.read_csv('data/survey_results_public_2020.csv')
# Out:
# C:\Users\indows 7\Anaconda2\envs\py3\lib\site-packages\IPython\core\interactiveshell.py:2714: DtypeWarning: Columns (8,12,13,14,15,16,50,51,52,53,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#display the data
df_2020.head()

# %%
df_2019.head()

# %%
df_2018.head()

# %%
def plot_bar_chart(df, column, title):
    vals = df[column].value_counts()
    plt.figure(figsize=(14,8))
    (vals[:30]/df.shape[0]).plot(kind="bar")
    plt.title(title, fontsize=24)

# %%
plot_bar_chart(df_2020,"Country","Stackoverflow Survey - Different countries responded")

# %% [markdown]
# We would need to filter down the data where country is India

# %%
plot_bar_chart(df_2020,"LanguageWorkedWith","Stackoverflow Survey - Language people are working with")

# %% [markdown]
# Each response contains multiple languages, we would need to extract the language individually from the columns. Same is the case with LanguageDesireNextYear

# %%
plot_bar_chart(df_2020,"LanguageDesireNextYear","Stackoverflow Survey - Language people want to learn")

# %% [markdown]
# This is interestnig as most of the people has provided a single reponse as python for desire language they want to learn. Lets look into gender fileld as well

# %%
plot_bar_chart(df_2020,"Gender","Stackoverflow Survey : 2020")

# %% [markdown]
# We will be ignoring the responses from the categories other then men and women due to low number of responses.
#
# # 3. Data Preparation
#
# For the categorical variable like country, we will filter it on India.
#
# For the variables such as LanguageWorkedWith & LanguageDesireNextYear, we will be <b> dropping the responses with missing values </b>.

# %%
##subsetting the data by country and selecting the variables
def subset_country(df, column_filter, country, columns):
    
    ''' Filter a dataframe by country.,
        returns filtred dataframe.
    '''
    
    df_v1 = df
    
    for column in columns: 
        df_v1 = df_v1[df_v1[column_filter] == country].dropna(subset=[column])
        
    return df_v1

# %%
In_2018 = subset_country(df_2018, 'Country', 'India', ['Respondent','LanguageWorkedWith', 'LanguageDesireNextYear'])
In_2019 = subset_country(df_2019, 'Country', 'India', ['Respondent','LanguageWorkedWith', 'LanguageDesireNextYear'])
In_2020 = subset_country(df_2020, 'Country', 'India', ['Respondent','LanguageWorkedWith', 'LanguageDesireNextYear'])

# %%
In_2018.head()
# Out:
#     Respondent Hobby OpenSource Country         Student          Employment  \
# 13          20    No         No   India              No  Employed full-time
# 18          29   Yes        Yes   India  Yes, full-time  Employed full-time
# 24          39   Yes         No   India              No  Employed full-time
# 41          61   Yes         No   India              No  Employed full-time
# 44          67   Yes         No   India              No  Employed full-time
#
#                                       FormalEducation  \
# 13           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 18           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 24        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 41  Some college/university study without earning ...
# 44           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                        UndergradMajor  \
# 13  Another engineering discipline (ex. civil, ele...
# 18                                                NaN
# 24  Computer science, computer engineering, or sof...
# 41  Another engineering discipline (ex. civil, ele...
# 44  Computer science, computer engineering, or sof...
#
#                  CompanySize  \
# 13        20 to 99 employees
# 18  10,000 or more employees
# 24      100 to 499 employees
# 41        20 to 99 employees
# 44        20 to 99 employees
#
#                                               DevType YearsCoding  \
# 13            Back-end developer;Full-stack developer   3-5 years
# 18  Data or business analyst;Data scientist or mac...   0-2 years
# 24                                   Mobile developer   3-5 years
# 41                       Designer;Front-end developer   0-2 years
# 44             Back-end developer;Front-end developer   6-8 years
#
#    YearsCodingProf        JobSatisfaction                  CareerSatisfaction  \
# 13       3-5 years    Extremely satisfied                Moderately satisfied
# 18       3-5 years     Slightly satisfied                 Extremely satisfied
# 24       3-5 years   Moderately satisfied                Moderately satisfied
# 41       0-2 years     Slightly satisfied               Slightly dissatisfied
# 44       0-2 years  Slightly dissatisfied  Neither satisfied nor dissatisfied
#
#                                         HopeFiveYears  \
# 13  Working as an engineering manager or other fun...
# 18                                Doing the same work
# 24  Working as a founder or co-founder of my own c...
# 41  Working in a different or more specialized tec...
# 44  Working in a different or more specialized tec...
#
#                                       JobSearchStatus  \
# 13  I’m not actively looking, but I am open to new...
# 18  I’m not actively looking, but I am open to new...
# 24  I’m not actively looking, but I am open to new...
# 41  I’m not actively looking, but I am open to new...
# 44  I’m not actively looking, but I am open to new...
#
#                    LastNewJob  AssessJob1  AssessJob2  AssessJob3  AssessJob4  \
# 13       Less than a year ago         6.0         9.0         2.0         4.0
# 18  Between 1 and 2 years ago         NaN         NaN         NaN         NaN
# 24  Between 1 and 2 years ago         NaN         NaN         NaN         NaN
# 41  Between 1 and 2 years ago         3.0         5.0         9.0         1.0
# 44       Less than a year ago         4.0         9.0         5.0         7.0
#
#     AssessJob5  AssessJob6  AssessJob7  AssessJob8  AssessJob9  AssessJob10  \
# 13         3.0         5.0         8.0         7.0        10.0          1.0
# 18         NaN         NaN         NaN         NaN         NaN          NaN
# 24         NaN         NaN         NaN         NaN         NaN          NaN
# 41         7.0         4.0        10.0         2.0         8.0          6.0
# 44         2.0        10.0         6.0         3.0         1.0          8.0
#
#     AssessBenefits1  AssessBenefits2  AssessBenefits3  AssessBenefits4  \
# 13              5.0              2.0              1.0             11.0
# 18              NaN              NaN              NaN              NaN
# 24              NaN              NaN              NaN              NaN
# 41              7.0             11.0              1.0              3.0
# 44              5.0              6.0              9.0              2.0
#
#     AssessBenefits5  AssessBenefits6  AssessBenefits7  AssessBenefits8  \
# 13              6.0              8.0             10.0              4.0
# 18              NaN              NaN              NaN              NaN
# 24              NaN              NaN              NaN              NaN
# 41              9.0              4.0             10.0              6.0
# 44              1.0              3.0              4.0              7.0
#
#     AssessBenefits9  AssessBenefits10  AssessBenefits11  \
# 13              7.0               3.0               9.0
# 18              NaN               NaN               NaN
# 24              NaN               NaN               NaN
# 41              2.0               8.0               5.0
# 44             10.0              11.0               8.0
#
#     JobContactPriorities1  JobContactPriorities2  JobContactPriorities3  \
# 13                    NaN                    NaN                    NaN
# 18                    NaN                    NaN                    NaN
# 24                    NaN                    NaN                    NaN
# 41                    2.0                    1.0                    5.0
# 44                    NaN                    NaN                    NaN
#
#     JobContactPriorities4  JobContactPriorities5  JobEmailPriorities1  \
# 13                    NaN                    NaN                  NaN
# 18                    NaN                    NaN                  NaN
# 24                    NaN                    NaN                  NaN
# 41                    3.0                    4.0                  4.0
# 44                    NaN                    NaN                  NaN
#
#     JobEmailPriorities2  JobEmailPriorities3  JobEmailPriorities4  \
# 13                  NaN                  NaN                  NaN
# 18                  NaN                  NaN                  NaN
# 24                  NaN                  NaN                  NaN
# 41                  3.0                  2.0                  1.0
# 44                  NaN                  NaN                  NaN
#
#     JobEmailPriorities5  JobEmailPriorities6  JobEmailPriorities7  \
# 13                  NaN                  NaN                  NaN
# 18                  NaN                  NaN                  NaN
# 24                  NaN                  NaN                  NaN
# 41                  7.0                  6.0                  5.0
# 44                  NaN                  NaN                  NaN
#
#                                     UpdateCV           Currency  Salary  \
# 13                                       NaN                NaN     NaN
# 18                  A recruiter contacted me                NaN     NaN
# 24                                       NaN  Indian rupees (₹)  700000
# 41                  A recruiter contacted me  Indian rupees (₹)  660000
# 44  A friend told me about a job opportunity  Indian rupees (₹)     NaN
#
#    SalaryType  ConvertedSalary CurrencySymbol  \
# 13        NaN              NaN            NaN
# 18    Monthly              NaN            NaN
# 24     Yearly          10958.0            INR
# 41    Monthly         123984.0            INR
# 44        NaN              NaN            NaN
#
#                                    CommunicationTools TimeFullyProductive  \
# 13                                                NaN                 NaN
# 18                                                NaN                 NaN
# 24  Facebook;Google Hangouts/Chat;Jira;Office / pr...   Less than a month
# 41  Other chat system (IRC, proprietary software, ...   Less than a month
# 44                                               Jira                 NaN
#
#                                        EducationTypes  \
# 13                                                NaN
# 18                Contributed to open source software
# 24  Taken a part-time in-person course in programm...
# 41  Taught yourself a new language, framework, or ...
# 44  Received on-the-job training in software devel...
#
#                                       SelfTaughtTypes TimeAfterBootcamp  \
# 13                                                NaN               NaN
# 18                                                NaN               NaN
# 24                                                NaN               NaN
# 41  A book or e-book from O’Reilly, Apress, or a s...               NaN
# 44  The official documentation and/or standards fo...               NaN
#
#    HackathonReasons  AgreeDisagree1              AgreeDisagree2  \
# 13              NaN             NaN                         NaN
# 18              NaN  Strongly agree              Strongly agree
# 24              NaN           Agree  Neither Agree nor Disagree
# 41              NaN           Agree                       Agree
# 44              NaN           Agree                       Agree
#
#        AgreeDisagree3                         LanguageWorkedWith  \
# 13                NaN                                       Java
# 18     Strongly agree                                   C;C++;C#
# 24  Strongly disagree     C;C++;Java;JavaScript;SQL;Swift;Kotlin
# 41              Agree                               PHP;HTML;CSS
# 44           Disagree  C;C++;Java;JavaScript;PHP;Python;HTML;CSS
#
#              LanguageDesireNextYear  \
# 13                      Java;Python
# 18                         Python;R
# 24     Java;JavaScript;Swift;Kotlin
# 41   C#;JavaScript;PHP;SQL;HTML;CSS
# 44  Java;JavaScript;Python;HTML;CSS
#
#                             DatabaseWorkedWith  \
# 13  MongoDB;MySQL;Oracle;MariaDB;Elasticsearch
# 18                                         NaN
# 24                            SQL Server;MySQL
# 41                                MySQL;SQLite
# 44                            SQL Server;MySQL
#
#                                DatabaseDesireNextYear    PlatformWorkedWith  \
# 13  MongoDB;MySQL;Oracle;MariaDB;Apache HBase;Elas...                 Linux
# 18                            Redis;PostgreSQL;Oracle                   NaN
# 24                                              MySQL  Android;iOS;Firebase
# 41                                       MySQL;SQLite                   NaN
# 44                                      MongoDB;MySQL      Android;Firebase
#
#           PlatformDesireNextYear        FrameworkWorkedWith  \
# 13                         Linux                     Spring
# 18  Azure;ESP8266;Gaming console                    Angular
# 24          Android;iOS;Firebase            Angular;Cordova
# 41          Android;iOS;Firebase  Angular;.NET Core;Node.js
# 44                           NaN                        NaN
#
#               FrameworkDesireNextYear  \
# 13                Hadoop;Spark;Spring
# 18                             Django
# 24                            Cordova
# 41  Angular;.NET Core;Node.js;Xamarin
# 44                     Angular;Django
#
#                                                   IDE OperatingSystem  \
# 13                                   Eclipse;NetBeans     Linux-based
# 18                          Android Studio;Coda;Xcode         Windows
# 24  Android Studio;Eclipse;IntelliJ;Notepad++;Subl...           MacOS
# 41    Android Studio;Visual Studio;Visual Studio Code         Windows
# 44     IntelliJ;Notepad++;PHPStorm;Visual Studio Code         Windows
#
#    NumberMonitors  Methodology VersionControl             CheckInCode  \
# 13    More than 4        Agile            Git  Multiple times per day
# 18    More than 4        Agile            Git                   Never
# 24              1        Agile            Git  Multiple times per day
# 41              1  Agile;Scrum            Git  Multiple times per day
# 44              1          NaN            Git              Once a day
#
#                     AdBlocker AdBlockerDisable AdBlockerReasons  \
# 13                        Yes               No              NaN
# 18  I'm not sure/I don't know              NaN              NaN
# 24                         No              NaN              NaN
# 41                         No              NaN              NaN
# 44                        Yes               No              NaN
#
#     AdsAgreeDisagree1           AdsAgreeDisagree2           AdsAgreeDisagree3  \
# 13     Strongly agree                         NaN                         NaN
# 18  Strongly disagree           Strongly disagree           Strongly disagree
# 24     Somewhat agree              Strongly agree           Somewhat disagree
# 41  Somewhat disagree              Somewhat agree  Neither agree nor disagree
# 44     Somewhat agree  Neither agree nor disagree  Neither agree nor disagree
#
#                                            AdsActions  AdsPriorities1  \
# 13  Stopped going to a website because of their ad...             NaN
# 18  Clicked on an online advertisement;Saw an onli...             NaN
# 24  Clicked on an online advertisement;Saw an onli...             NaN
# 41  Clicked on an online advertisement;Saw an onli...             5.0
# 44                                                NaN             5.0
#
#     AdsPriorities2  AdsPriorities3  AdsPriorities4  AdsPriorities5  \
# 13             NaN             NaN             NaN             NaN
# 18             NaN             NaN             NaN             NaN
# 24             NaN             NaN             NaN             NaN
# 41             3.0             1.0             6.0             2.0
# 44             6.0             1.0             7.0             4.0
#
#     AdsPriorities6  AdsPriorities7  \
# 13             NaN             NaN
# 18             NaN             NaN
# 24             NaN             NaN
# 41             7.0             4.0
# 44             2.0             3.0
#
#                                           AIDangerous  \
# 13                      Increasing automation of jobs
# 18                      Increasing automation of jobs
# 24  Evolving definitions of "fairness" in algorith...
# 41  Artificial intelligence surpassing human intel...
# 44  Artificial intelligence surpassing human intel...
#
#                                         AIInteresting  \
# 13              Algorithms making important decisions
# 18  Evolving definitions of "fairness" in algorith...
# 24                      Increasing automation of jobs
# 41                      Increasing automation of jobs
# 44  Evolving definitions of "fairness" in algorith...
#
#                                    AIResponsible  \
# 13  The developers or the people creating the AI
# 18  The developers or the people creating the AI
# 24                    Prominent industry leaders
# 41  The developers or the people creating the AI
# 44  The developers or the people creating the AI
#
#                                              AIFuture           EthicsChoice  \
# 13  I'm excited about the possibilities more than ...  Depends on what it is
# 18  I'm worried about the dangers more than I'm ex...                     No
# 24  I'm excited about the possibilities more than ...                    Yes
# 41  I'm excited about the possibilities more than ...  Depends on what it is
# 44  I'm worried about the dangers more than I'm ex...  Depends on what it is
#
#                         EthicsReport                     EthicsResponsible  \
# 13  Yes, but only within the company            The developer who wrote it
# 18                                No            The developer who wrote it
# 24  Yes, but only within the company            The developer who wrote it
# 41             Depends on what it is  The person who came up with the idea
# 44             Depends on what it is  The person who came up with the idea
#
#       EthicalImplications StackOverflowRecommend      StackOverflowVisit  \
# 13                    Yes       10 (Very Likely)  Multiple times per day
# 18                     No       10 (Very Likely)  Multiple times per day
# 24                    Yes       10 (Very Likely)   Daily or almost daily
# 41                     No       10 (Very Likely)   Daily or almost daily
# 44  Unsure / I don't know       10 (Very Likely)  Multiple times per day
#
#             StackOverflowHasAccount  \
# 13                              Yes
# 18  I'm not sure / I can't remember
# 24                              Yes
# 41                              Yes
# 44                              Yes
#
#                              StackOverflowParticipate  \
# 13                              Daily or almost daily
# 18                                                NaN
# 24                Less than once per month or monthly
# 41                Less than once per month or monthly
# 44  I have never participated in Q&A on Stack Over...
#
#                                     StackOverflowJobs  \
# 13                                                Yes
# 18                                                Yes
# 24                                                Yes
# 41  No, I didn't know that Stack Overflow had a jo...
# 44  No, I knew that Stack Overflow had a jobs boar...
#
#                          StackOverflowDevStory StackOverflowJobsRecommend  \
# 13           No, and I don't know what that is           10 (Very Likely)
# 18                                         NaN           10 (Very Likely)
# 24           No, and I don't know what that is           10 (Very Likely)
# 41           No, and I don't know what that is                        NaN
# 44  No, I know what it is but I don't have one                        NaN
#
#    StackOverflowConsiderMember   HypotheticalTools1    HypotheticalTools2  \
# 13                         Yes  Somewhat interested  Extremely interested
# 18                I'm not sure                  NaN                   NaN
# 24                         Yes  Somewhat interested  Extremely interested
# 41                I'm not sure                  NaN       Very interested
# 44                          No      Very interested  Extremely interested
#
#       HypotheticalTools3       HypotheticalTools4    HypotheticalTools5  \
# 13  Extremely interested  A little bit interested   Somewhat interested
# 18                   NaN                      NaN  Extremely interested
# 24  Extremely interested          Very interested       Very interested
# 41       Very interested      Somewhat interested   Somewhat interested
# 44  Extremely interested     Extremely interested  Extremely interested
#
#                         WakeTime HoursComputer HoursOutside  \
# 13        Between 6:01 - 7:00 AM   5 - 8 hours  1 - 2 hours
# 18  I do not have a set schedule  9 - 12 hours  1 - 2 hours
# 24        Between 6:01 - 7:00 AM  9 - 12 hours  1 - 2 hours
# 41        Between 6:01 - 7:00 AM  9 - 12 hours  3 - 4 hours
# 44        Between 7:01 - 8:00 AM   5 - 8 hours  1 - 2 hours
#
#                SkipMeals                           ErgonomicDevices  \
# 13                 Never                Ergonomic keyboard or mouse
# 18  3 - 4 times per week                Fatigue-relieving floor mat
# 24  1 - 2 times per week  Standing desk;Ergonomic keyboard or mouse
# 41                 Never                                        NaN
# 44                 Never  Standing desk;Ergonomic keyboard or mouse
#
#                       Exercise       Gender         SexualOrientation  \
# 13  I don't typically exercise          NaN                       NaN
# 18   Daily or almost every day       Female                       NaN
# 24   Daily or almost every day  Female;Male                       NaN
# 41  I don't typically exercise         Male  Straight or heterosexual
# 44        3 - 4 times per week         Male                       NaN
#
#                                      EducationParents RaceEthnicity  \
# 13                                                NaN           NaN
# 18  Some college/university study without earning ...           NaN
# 24                                                NaN           NaN
# 41           Bachelor’s degree (BA, BS, B.Eng., etc.)   South Asian
# 44  Secondary school (e.g. American high school, G...   South Asian
#
#                   Age Dependents MilitaryUS  \
# 13                NaN        NaN        NaN
# 18                NaN        NaN        NaN
# 24  25 - 34 years old         No        NaN
# 41  35 - 44 years old        Yes        NaN
# 44  18 - 24 years old         No        NaN
#
#                            SurveyTooLong                  SurveyEasy
# 13                                   NaN                         NaN
# 18               The survey was too long              Very difficult
# 24               The survey was too long                   Very easy
# 41  The survey was an appropriate length  Neither easy nor difficult
# 44               The survey was too long                   Very easy

# %%
In_2019.head()
# Out:
#     Respondent                              MainBranch Hobbyist  \
# 7            8             I code primarily as a hobby      Yes
# 9           10          I am a developer by profession      Yes
# 14          15  I am a student who is learning to code      Yes
# 49          50          I am a developer by profession      Yes
# 64          65          I am a developer by profession      Yes
#
#                    OpenSourcer  \
# 7      Less than once per year
# 9   Once a month or more often
# 14                       Never
# 49  Once a month or more often
# 64                       Never
#
#                                            OpenSource  \
# 7   OSS is, on average, of HIGHER quality than pro...
# 9   OSS is, on average, of HIGHER quality than pro...
# 14  OSS is, on average, of HIGHER quality than pro...
# 49  OSS is, on average, of LOWER quality than prop...
# 64                                                NaN
#
#                             Employment Country         Student  \
# 7   Not employed, but looking for work   India             NaN
# 9                   Employed full-time   India              No
# 14  Not employed, but looking for work   India  Yes, full-time
# 49                  Employed full-time   India              No
# 64                  Employed full-time   India              No
#
#                                               EdLevel  \
# 7            Bachelor’s degree (BA, BS, B.Eng., etc.)
# 9         Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 14  Secondary school (e.g. American high school, G...
# 49           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 64           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                        UndergradMajor  \
# 7   Computer science, computer engineering, or sof...
# 9                                                 NaN
# 14                                                NaN
# 49  Another engineering discipline (ex. civil, ele...
# 64  Information systems, information technology, o...
#
#                                              EduOther  \
# 7   Taught yourself a new language, framework, or ...
# 9                                                 NaN
# 14  Taken an online course in programming or softw...
# 49  Received on-the-job training in software devel...
# 64                                                NaN
#
#                      OrgSize  \
# 7                        NaN
# 9   10,000 or more employees
# 14                       NaN
# 49  10,000 or more employees
# 64        20 to 99 employees
#
#                                               DevType YearsCode Age1stCode  \
# 7      Developer, back-end;Engineer, site reliability         8         16
# 9   Data or business analyst;Data scientist or mac...        12         20
# 14                                            Student         3         13
# 49              Developer, back-end;DevOps specialist         7         15
# 64             Developer, front-end;Developer, mobile         2         17
#
#    YearsCodePro              CareerSat                 JobSat  \
# 7           NaN                    NaN                    NaN
# 9            10  Slightly dissatisfied  Slightly dissatisfied
# 14          NaN                    NaN                    NaN
# 49            2     Slightly satisfied         Very satisfied
# 64            2         Very satisfied         Very satisfied
#
#               MgrIdiot  MgrMoney   MgrWant  \
# 7                  NaN       NaN       NaN
# 9   Somewhat confident       Yes       Yes
# 14                 NaN       NaN       NaN
# 49      Very confident  Not sure       Yes
# 64      Very confident        No  Not sure
#
#                                               JobSeek          LastHireDate  \
# 7                                                 NaN                   NaN
# 9   I’m not actively looking, but I am open to new...         3-4 years ago
# 14  I’m not actively looking, but I am open to new...  I've never had a job
# 49  I’m not actively looking, but I am open to new...         1-2 years ago
# 64  I’m not actively looking, but I am open to new...  Less than a year ago
#
#                                               LastInt FizzBuzz  \
# 7                                                 NaN      NaN
# 9                                                 NaN       No
# 14                                                NaN      NaN
# 49  Write code by hand (e.g., on a whiteboard);Int...       No
# 64  Write any code;Solve a brain-teaser style puzz...       No
#
#                                            JobFactors  \
# 7                                                 NaN
# 9   Languages, frameworks, and other technologies ...
# 14  Industry that I'd be working in;Languages, fra...
# 49  Specific department or team I'd be working on;...
# 64  Languages, frameworks, and other technologies ...
#
#                                          ResumeUpdate CurrencySymbol  \
# 7                                                 NaN            NaN
# 9                                                 NaN            INR
# 14  Something else changed (education, award, medi...            NaN
# 49                   I was preparing for a job search            INR
# 64   My job status changed (promotion, new job, etc.)            INR
#
#     CurrencyDesc  CompTotal CompFreq  ConvertedComp  WorkWeekHrs  \
# 7            NaN        NaN      NaN            NaN          NaN
# 9   Indian rupee   950000.0   Yearly        13293.0         70.0
# 14           NaN        NaN      NaN            NaN          NaN
# 49  Indian rupee   400000.0   Yearly         5597.0          7.0
# 64  Indian rupee        NaN  Monthly            NaN         48.0
#
#                                              WorkPlan  \
# 7                                                 NaN
# 9   There's no schedule or spec; I work on what se...
# 14                                                NaN
# 49  There is a schedule and/or spec (made by me or...
# 64  There's no schedule or spec; I work on what se...
#
#                     WorkChallenge                        WorkRemote  \
# 7                             NaN                               NaN
# 9                             NaN             A few days each month
# 14                            NaN                               NaN
# 49  Meetings;Time spent commuting  Less than once per month / Never
# 64                            NaN               About half the time
#
#                                            WorkLoc             ImpSyn  \
# 7                                              NaN                NaN
# 9                                             Home  Far above average
# 14                                             NaN                NaN
# 49  Other place, such as a coworking space or cafe            Average
# 64                                          Office            Average
#
#                                     CodeRev  CodeRevHrs  \
# 7                                       NaN         NaN
# 9   Yes, because I see value in code review         4.0
# 14                                      NaN         NaN
# 49                                       No         NaN
# 64  Yes, because I see value in code review         NaN
#
#                                             UnitTests  \
# 7                                                 NaN
# 9                       Yes, it's part of our process
# 14                                                NaN
# 49  Yes, it's not part of our process but the deve...
# 64  Yes, it's not part of our process but the deve...
#
#                                           PurchaseHow  \
# 7                                                 NaN
# 9                                                 NaN
# 14                                                NaN
# 49  The CTO, CIO, or other management purchase new...
# 64                                           Not sure
#
#                      PurchaseWhat  \
# 7                             NaN
# 9                             NaN
# 14                            NaN
# 49  I have little or no influence
# 64                            NaN
#
#                                    LanguageWorkedWith  \
# 7   Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 9                       C#;Go;JavaScript;Python;R;SQL
# 14  Assembly;Bash/Shell/PowerShell;C;C++;HTML/CSS;...
# 49  Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 64                    Assembly;C;C++;C#;HTML/CSS;Java
#
#                                LanguageDesireNextYear  \
# 7   Bash/Shell/PowerShell;C;C++;Elixir;Erlang;Go;P...
# 9                C#;Go;JavaScript;Kotlin;Python;R;SQL
# 14  Assembly;Bash/Shell/PowerShell;C;C++;C#;Go;HTM...
# 49                         HTML/CSS;JavaScript;Python
# 64                                             Kotlin
#
#                                    DatabaseWorkedWith  \
# 7   Cassandra;Elasticsearch;MongoDB;MySQL;Oracle;R...
# 9   Elasticsearch;MongoDB;Microsoft SQL Server;MyS...
# 14                        MariaDB;MySQL;Oracle;SQLite
# 49  Elasticsearch;Firebase;MariaDB;MongoDB;MySQL;O...
# 64                       Firebase;MySQL;Oracle;SQLite
#
#                                DatabaseDesireNextYear  \
# 7   Cassandra;DynamoDB;Elasticsearch;Firebase;Mong...
# 9          Elasticsearch;MongoDB;Microsoft SQL Server
# 14  MariaDB;MongoDB;Microsoft SQL Server;MySQL;Ora...
# 49                Firebase;PostgreSQL;Redis;Other(s):
# 64                                    Firebase;SQLite
#
#                                    PlatformWorkedWith  \
# 7                 AWS;Docker;Heroku;Linux;MacOS;Slack
# 9                                       Linux;Windows
# 14                                      Linux;Windows
# 49  Arduino;AWS;Heroku;Linux;MacOS;Raspberry Pi;Wo...
# 64                                            Android
#
#                                PlatformDesireNextYear  \
# 7   Android;Arduino;AWS;Docker;Google Cloud Platfo...
# 9                  Android;Linux;Raspberry Pi;Windows
# 14  Android;Google Cloud Platform;iOS;Linux;MacOS;...
# 49  AWS;Docker;Heroku;Kubernetes;Linux;MacOS;WordP...
# 64                                            Android
#
#                                    WebFrameWorkedWith  \
# 7                       Express;Flask;React.js;Spring
# 9   Angular/Angular.js;ASP.NET;Django;Express;Flas...
# 14                                                NaN
# 49                        Django;Express;Flask;jQuery
# 64                                            ASP.NET
#
#                                WebFrameDesireNextYear  \
# 7                Django;Express;Flask;React.js;Vue.js
# 9   Angular/Angular.js;ASP.NET;Django;Express;Flas...
# 14  Angular/Angular.js;ASP.NET;Django;Drupal;jQuer...
# 49               Express;Flask;jQuery;React.js;Vue.js
# 64                                                NaN
#
#                    MiscTechWorkedWith  \
# 7               Hadoop;Node.js;Pandas
# 9   .NET;Node.js;Pandas;Torch/PyTorch
# 14                                NaN
# 49                            Node.js
# 64                                NaN
#
#                                MiscTechDesireNextYear  \
# 7   Ansible;Apache Spark;Chef;Hadoop;Node.js;Panda...
# 9               .NET;Node.js;TensorFlow;Torch/PyTorch
# 14  .NET;.NET Core;Node.js;TensorFlow;Unity 3D;Unr...
# 49                                            Node.js
# 64                                                NaN
#
#                                            DevEnviron        OpSys  \
# 7   Atom;IntelliJ;IPython / Jupyter;PyCharm;Visual...  Linux-based
# 9   Android Studio;Eclipse;IPython / Jupyter;Notep...      Windows
# 14           Atom;NetBeans;Notepad++;Sublime Text;Vim  Linux-based
# 49                       Notepad++;Visual Studio Code        MacOS
# 64                            Android Studio;IntelliJ  Linux-based
#
#                                            Containers BlockchainOrg  \
# 7   Development;Testing;Production;Outside of work...           NaN
# 9                                                 NaN    Not at all
# 14                                        Development           NaN
# 49                                            Testing    Not at all
# 64                                                NaN           NaN
#
#                                          BlockchainIs BetterLife  ITperson  \
# 7   Useful across many domains and could change ma...        Yes      SIGH
# 9   Useful for immutable record keeping outside of...         No       Yes
# 14                                                NaN        Yes       Yes
# 49  Useful for immutable record keeping outside of...        Yes  Also Yes
# 64                                                NaN        Yes       Yes
#
#     OffOn SocialMedia              Extraversion   ScreenName SOVisit1st  \
# 7     Yes     YouTube  In real life (in person)       Handle       2012
# 9     Yes     YouTube                   Neither  Screen Name        NaN
# 14  What?     YouTube  In real life (in person)          NaN       2018
# 49  What?     YouTube  In real life (in person)     Username       2012
# 64  What?    WhatsApp  In real life (in person)          NaN       2017
#
#                SOVisitFreq                                          SOVisitTo  \
# 7     A few times per week  Find answers to specific questions;Learn how t...
# 9   Multiple times per day  Find answers to specific questions;Get a sense...
# 14   Daily or almost daily  Find answers to specific questions;Learn how t...
# 49   Daily or almost daily  Find answers to specific questions;Learn how t...
# 64  Multiple times per day                 Find answers to specific questions
#
#                    SOFindAnswer                         SOTimeSaved  \
# 7       Less than once per week  Stack Overflow was slightly faster
# 9            3-5 times per week            They were about the same
# 14  More than 10 times per week            They were about the same
# 49           3-5 times per week  Stack Overflow was slightly faster
# 64  More than 10 times per week  Stack Overflow was slightly faster
#
#     SOHowMuchTime SOAccount                           SOPartFreq  \
# 7   11-30 minutes       Yes  Less than once per month or monthly
# 9             NaN       Yes      A few times per month or weekly
# 14            NaN       Yes  Less than once per month or monthly
# 49  11-30 minutes       Yes  Less than once per month or monthly
# 64  11-30 minutes       Yes                 A few times per week
#
#                                                SOJobs  \
# 7                                                 Yes
# 9                                                 Yes
# 14                                                Yes
# 49  No, I knew that Stack Overflow had a job board...
# 64  No, I knew that Stack Overflow had a job board...
#
#                                              EntTeams           SOComm  \
# 7                 No, and I don't know what those are  Yes, definitely
# 9                 No, and I don't know what those are    Yes, somewhat
# 14  No, I've heard of them, but I am not part of a...    Yes, somewhat
# 49                No, and I don't know what those are  Yes, definitely
# 64                No, and I don't know what those are         Not sure
#
#                                WelcomeChange  \
# 7      A lot more welcome now than last year
# 9   Somewhat less welcome now than last year
# 14   Just as welcome now as I felt last year
# 49   Just as welcome now as I felt last year
# 64     A lot more welcome now than last year
#
#                                          SONewContent   Age Gender Trans  \
# 7   Tech articles written by other developers;Indu...  24.0    Man    No
# 9   Tech articles written by other developers;Tech...   NaN    NaN   NaN
# 14  Tech articles written by other developers;Indu...  20.0    Man    No
# 49  Tech articles written by other developers;Tech...  23.0    Man    No
# 64                                                NaN  21.0    Man    No
#
#                   Sexuality    Ethnicity Dependents           SurveyLength  \
# 7   Straight / Heterosexual          NaN        NaN  Appropriate in length
# 9                       NaN          NaN        Yes               Too long
# 14                      NaN          NaN        Yes               Too long
# 49                      NaN  South Asian         No               Too long
# 64                      NaN          NaN        Yes  Appropriate in length
#
#                     SurveyEase
# 7   Neither easy nor difficult
# 9                    Difficult
# 14  Neither easy nor difficult
# 49                        Easy
# 64  Neither easy nor difficult

# %%
In_2020.head()
# Out:
#      Respondent                              MainBranch Hobbyist   Age  \
# 6             7          I am a developer by profession      Yes   NaN
# 21           22          I am a developer by profession      Yes   NaN
# 57           58          I am a developer by profession      Yes   NaN
# 62           63  I am a student who is learning to code      Yes  21.0
# 147         149          I am a developer by profession      Yes  36.0
#
#     Age1stCode CompFreq   CompTotal  ConvertedComp Country  \
# 6           18  Monthly         NaN            NaN   India
# 21          18  Monthly         NaN            NaN   India
# 57          22      NaN         NaN            NaN   India
# 62          17      NaN         NaN            NaN   India
# 147         31   Yearly  21000000.0       293196.0   India
#
#              CurrencyDesc CurrencySymbol      DatabaseDesireNextYear  \
# 6    United States dollar            USD                         NaN
# 21           Indian rupee            INR                         NaN
# 57           Indian rupee            INR        Microsoft SQL Server
# 62                    NaN            NaN                    DynamoDB
# 147          Indian rupee            INR  Cassandra;MySQL;PostgreSQL
#
#          DatabaseWorkedWith  \
# 6                       NaN
# 21                      NaN
# 57     Microsoft SQL Server
# 62   Firebase;MongoDB;MySQL
# 147        MySQL;PostgreSQL
#
#                                                DevType  \
# 6    Developer, back-end;Developer, front-end;Devel...
# 21                Developer, full-stack;Engineer, data
# 57                                 Developer, back-end
# 62   Designer;Developer, back-end;Developer, front-...
# 147  Developer, back-end;Developer, QA or test;DevO...
#
#                                                EdLevel  \
# 6         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 21        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 57                                                 NaN
# 62   Secondary school (e.g. American high school, G...
# 147       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                             Employment    Ethnicity Gender  \
# 6                                   Employed full-time          NaN    NaN
# 21                                  Employed full-time          NaN    Man
# 57   Independent contractor, freelancer, or self-em...  South Asian    NaN
# 62                  Not employed, but looking for work  South Asian    Man
# 147                                 Employed full-time   East Asian    Man
#
#                                             JobFactors                 JobSat  \
# 6                                                  NaN         Very satisfied
# 21                                                 NaN  Slightly dissatisfied
# 57                                 Family friendliness         Very satisfied
# 62   Flex time or a flexible schedule;How widely us...                    NaN
# 147  Languages, frameworks, and other technologies ...         Very satisfied
#
#                                                JobSeek  \
# 6    I’m not actively looking, but I am open to new...
# 21                     I am actively looking for a job
# 57        I am not interested in new job opportunities
# 62                     I am actively looking for a job
# 147       I am not interested in new job opportunities
#
#                           LanguageDesireNextYear  \
# 6                                C#;HTML/CSS;PHP
# 21                        Java;JavaScript;Python
# 57                  C#;JavaScript;SQL;TypeScript
# 62                          Go;Kotlin;TypeScript
# 147  Bash/Shell/PowerShell;C;C++;Java;Perl;Scala
#
#                         LanguageWorkedWith  \
# 6                          C#;HTML/CSS;PHP
# 21                             Java;Python
# 57            C#;JavaScript;SQL;TypeScript
# 62   C;C++;HTML/CSS;Java;JavaScript;Python
# 147         Bash/Shell/PowerShell;C++;Perl
#
#                       MiscTechDesireNextYear      MiscTechWorkedWith  \
# 6                                        NaN                     NaN
# 21                                       NaN                     NaN
# 57                    .NET;.NET Core;Node.js  .NET;.NET Core;Node.js
# 62   Flutter;Node.js;React Native;TensorFlow                     NaN
# 147                             Apache Spark                     NaN
#
#                           NEWCollabToolsDesireNextYear  \
# 6                                                  NaN
# 21                                                 NaN
# 57                            Stack Overflow for Teams
# 62                 Confluence;Stack Overflow for Teams
# 147  Confluence;Jira;Github;Gitlab;Google Suite (Do...
#
#                               NEWCollabToolsWorkedWith NEWDevOps  \
# 6                                                  NaN       Yes
# 21                                                 NaN  Not sure
# 57                            Stack Overflow for Teams       Yes
# 62   Github;Facebook Workplace;Slack;Microsoft Team...       NaN
# 147  Confluence;Jira;Github;Google Suite (Docs, Mee...  Not sure
#
#            NEWDevOpsImpt             NEWEdImpt  \
# 6    Extremely important        Very important
# 21                   NaN        Very important
# 57   Extremely important        Very important
# 62                   NaN                   NaN
# 147              Neutral  Critically important
#
#                                             NEWJobHunt  \
# 6    Better compensation;Growth or leadership oppor...
# 21   Better compensation;Better work/life balance;W...
# 57                                                 NaN
# 62                                                 NaN
# 147  Just because;Curious about other opportunities...
#
#                                     NEWJobHuntResearch              NEWLearn  \
# 6    Read company media, such as employee blogs or ...      Every few months
# 21   Company reviews from third party sites (e.g. G...      Every few months
# 57                                                 NaN  Once every few years
# 62                                                 NaN           Once a year
# 147  Read company media, such as employee blogs or ...           Once a year
#
#     NEWOffTopic                NEWOnboardGood NEWOtherComms  \
# 6           Yes                           Yes            No
# 21           No                           Yes            No
# 57          NaN                           Yes            No
# 62          Yes                           NaN            No
# 147    Not sure  Onboarding? What onboarding?            No
#
#                                            NEWOvertime  \
# 6    Sometimes: 1-2 days per month but less than we...
# 21                    Often: 1-2 days per week or more
# 57                    Often: 1-2 days per week or more
# 62                                                 NaN
# 147  Sometimes: 1-2 days per month but less than we...
#
#                                    NEWPurchaseResearch      NEWPurpleLink  \
# 6    Start a free trial;Ask developers I know/work ...                NaN
# 21                                                 NaN                NaN
# 57                     Ask developers I know/work with  Hello, old friend
# 62   Start a free trial;Ask developers I know/work ...  Hello, old friend
# 147                                                NaN        Indifferent
#
#                                             NEWSOSites  \
# 6     Stack Overflow (public Q&A for anyone who codes)
# 21   Stack Overflow (public Q&A for anyone who code...
# 57   Stack Overflow (public Q&A for anyone who code...
# 62   Stack Overflow (public Q&A for anyone who code...
# 147   Stack Overflow (public Q&A for anyone who codes)
#
#                                               NEWStuck        OpSys  \
# 6                                                  NaN      Windows
# 21                                                 NaN      Windows
# 57   Call a coworker or friend;Visit Stack Overflow...      Windows
# 62   Visit Stack Overflow;Go for a walk or other ph...      Windows
# 147  Visit Stack Overflow;Go for a walk or other ph...  Linux-based
#
#                   OrgSize       PlatformDesireNextYear  \
# 6      20 to 99 employees                          NaN
# 21   500 to 999 employees                          NaN
# 57                    NaN                          NaN
# 62                    NaN        AWS;Docker;Heroku;iOS
# 147  500 to 999 employees  Google Cloud Platform;Linux
#
#                                     PlatformWorkedWith  \
# 6                                                  NaN
# 21                                                 NaN
# 57                                                 NaN
# 62   Android;Arduino;Google Cloud Platform;Raspberr...
# 147                                              Linux
#
#                       PurchaseWhat                Sexuality SOAccount  \
# 6                              NaN                      NaN       Yes
# 21                             NaN                      NaN       Yes
# 57                             NaN                      NaN       Yes
# 62                             NaN  Straight / Heterosexual       Yes
# 147  I have little or no influence  Straight / Heterosexual       Yes
#
#               SOComm                       SOPartFreq             SOVisitFreq  \
# 6    Yes, definitely           Multiple times per day  Multiple times per day
# 21   Yes, definitely           Multiple times per day  Multiple times per day
# 57   Yes, definitely                              NaN  Multiple times per day
# 62           Neutral             A few times per week   Daily or almost daily
# 147    Yes, somewhat  A few times per month or weekly  Multiple times per day
#
#                      SurveyEase           SurveyLength Trans  \
# 6                           NaN                    NaN   NaN
# 21                         Easy  Appropriate in length   NaN
# 57   Neither easy nor difficult               Too long   NaN
# 62                         Easy  Appropriate in length    No
# 147  Neither easy nor difficult  Appropriate in length    No
#
#                                         UndergradMajor  \
# 6    Computer science, computer engineering, or sof...
# 21   Computer science, computer engineering, or sof...
# 57                       Web development or web design
# 62                                                 NaN
# 147  Computer science, computer engineering, or sof...
#
#                              WebframeDesireNextYear  \
# 6                                               NaN
# 21                                              NaN
# 57   Angular;Angular.js;ASP.NET;ASP.NET Core;jQuery
# 62          Angular.js;Django;jQuery;Laravel;Vue.js
# 147                                             NaN
#
#                                  WebframeWorkedWith  \
# 6                                               NaN
# 21                                              NaN
# 57   Angular;Angular.js;ASP.NET;ASP.NET Core;jQuery
# 62                                              NaN
# 147                                             NaN
#
#                                          WelcomeChange  WorkWeekHrs YearsCode  \
# 6                A lot more welcome now than last year          NaN         6
# 21             Just as welcome now as I felt last year         50.0        10
# 57                                                 NaN          NaN       NaN
# 62   Not applicable - I did not use Stack Overflow ...          NaN         4
# 147           Somewhat more welcome now than last year         70.0         5
#
#     YearsCodePro
# 6              4
# 21             2
# 57           NaN
# 62           NaN
# 147            3

# %%
#Lets split the language column into series
def split_lang_column(df, column):
    ''' Split column by ;,
        returns a splited series.
    '''
    
    df_copy = df
    column_series = df_copy[column].apply(lambda x: x.split(';'))
    
    return column_series

# %%
worked_lang_2018 = split_lang_column(In_2018, 'LanguageWorkedWith')
wanted_lang_2018 = split_lang_column(In_2018, 'LanguageDesireNextYear')

worked_lang_2019 = split_lang_column(In_2019, 'LanguageWorkedWith')
wanted_lang_2019 = split_lang_column(In_2019, 'LanguageDesireNextYear')

worked_lang_2020 = split_lang_column(In_2020, 'LanguageWorkedWith')
wanted_lang_2020 = split_lang_column(In_2020, 'LanguageDesireNextYear')

# %%
# print the sample data
worked_lang_2018.head()
# Out:
# 13                                               [Java]
# 18                                         [C, C++, C#]
# 24       [C, C++, Java, JavaScript, SQL, Swift, Kotlin]
# 41                                     [PHP, HTML, CSS]
# 44    [C, C++, Java, JavaScript, PHP, Python, HTML, ...
# Name: LanguageWorkedWith, dtype: object

# %%
# disarraying the language column to have one row per language
def disarray(array_list):
    ''' Flat a nested list,
        returns a flat list.
    '''
    
    objects = []
    
    for row in array_list:
        for obj in row:
            # In the survey data in 2018, HTML and CSS were two sperate options, however, in 2019 & 2020 they are consider
            if obj == 'HTML' or obj== 'CSS' :
                obj='HTML/CSS'
            objects.append(obj.strip())
            
    return objects

list_worked_languages_2018 = disarray(worked_lang_2018)
list_wanted_languages_2018 = disarray(wanted_lang_2018)
list_worked_languages_2019 = disarray(worked_lang_2019)
list_wanted_languages_2019 = disarray(wanted_lang_2019)
list_worked_languages_2020 = disarray(worked_lang_2020)
list_wanted_languages_2020 = disarray(wanted_lang_2020)

# %%
# language count per year
def group_list(data_list, year):
    ''' Group by count to a list,
        returns a result dict.
    '''
    
    grouped_list = dict(collections.Counter(data_list))
    grouped_dict = [{'Programming Language':key, 'Count': value, 'Year': year} for key, value in grouped_list.items()]
    
    return grouped_dict

# Groping a list and creating a dict.

dict_worked_languages_2018 = group_list(list_worked_languages_2018, '2018')
dict_wanted_languages_2018 = group_list(list_wanted_languages_2018, '2018')

dict_worked_languages_2019 = group_list(list_worked_languages_2019, '2019')
dict_wanted_languages_2019 = group_list(list_wanted_languages_2019, '2019')

dict_worked_languages_2020 = group_list(list_worked_languages_2020, '2020')
dict_wanted_languages_2020 = group_list(list_wanted_languages_2020, '2020')

# %%
# createing the dataframe from sictionary and appending all dataframes
def create_append_dataframe(data_dicts):
    ''' Create two dataframes and append them,
        returns a appended dataframe.
    '''
        
    df1 = pd.DataFrame(data_dicts[0])
    df2 = pd.DataFrame(data_dicts[1])
    df3 = pd.DataFrame(data_dicts[2])

    df = df1.append(df2).append(df3)
    
    return df

# Creating a Data Frame appending the data.
worked_languages = create_append_dataframe([dict_worked_languages_2018, dict_worked_languages_2019, dict_worked_languages_2020])
wanted_languages = create_append_dataframe([dict_wanted_languages_2018, dict_wanted_languages_2019, dict_wanted_languages_2020])

# %%
#population percentage of each year for survey participatns
def pop_percentage(df, column):
    ''' Scale data,
        returns data scaled.
    '''
    
    df_copy = df
    series = []
    
    for val in df_copy[column].unique():
        series.append(df_copy[df_copy[column] == val]['Count'] / 
                      df_copy[df_copy[column] == val]['Count'].sum())
    
    joined_series = pd.Series()
    for i_series in series:
        joined_series = joined_series.append(i_series)
        
    return joined_series

# %%
#We will only keep Men and Women and will get rid off the other categories as we have low responses
In_2020_Man=subset_country(df_2020, 'Gender', 'Man', ['Respondent','LanguageWorkedWith'])
In_2020_Woman=subset_country(df_2020, 'Gender', 'Woman', ['Respondent','LanguageWorkedWith'])

# %%
In_2020_Woman.head()
# Out:
#     Respondent                              MainBranch Hobbyist   Age  \
# 34          35  I am a student who is learning to code      Yes  16.0
# 39          40  I am a student who is learning to code      Yes  20.0
# 55          56          I am a developer by profession      Yes  27.0
# 65          66          I am a developer by profession      Yes  21.0
# 84          85          I am a developer by profession      Yes  21.0
#
#    Age1stCode CompFreq  CompTotal  ConvertedComp        Country  \
# 34         13      NaN        NaN            NaN  United States
# 39         14      NaN        NaN            NaN  United States
# 55         21      NaN        NaN            NaN  United States
# 65          9      NaN        NaN            NaN         Canada
# 84         15   Weekly        NaN            NaN  United States
#
#             CurrencyDesc CurrencySymbol DatabaseDesireNextYear  \
# 34                   NaN            NaN          MongoDB;MySQL
# 39                   NaN            NaN                  MySQL
# 55  United States dollar            USD          Elasticsearch
# 65                   NaN            NaN      PostgreSQL;SQLite
# 84  United States dollar            USD                MariaDB
#
#                                    DatabaseWorkedWith  \
# 34                                      MongoDB;MySQL
# 39                                       MySQL;SQLite
# 55                               DynamoDB;MySQL;Redis
# 65                                  PostgreSQL;SQLite
# 84  MariaDB;Microsoft SQL Server;MongoDB;MySQL;Ora...
#
#                                               DevType  \
# 34                      Designer;Developer, front-end
# 39                                                NaN
# 55                              Developer, full-stack
# 65                                                NaN
# 84  Developer, back-end;Developer, desktop or ente...
#
#                                               EdLevel  \
# 34       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 39                Associate degree (A.A., A.S., etc.)
# 55       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65                                                NaN
# 84  Some college/university study without earning ...
#
#                             Employment                     Ethnicity Gender  \
# 34  Not employed, but looking for work  White or of European descent  Woman
# 39                             Student        Hispanic or Latino/a/x  Woman
# 55                  Employed full-time  White or of European descent  Woman
# 65                             Student                           NaN  Woman
# 84                  Employed part-time  White or of European descent  Woman
#
#                                            JobFactors          JobSat  \
# 34  Flex time or a flexible schedule;Remote work o...             NaN
# 39  Industry that I’d be working in;Flex time or a...             NaN
# 55  Diversity of the company or organization;Speci...  Very satisfied
# 65  Industry that I’d be working in;Flex time or a...             NaN
# 84  Flex time or a flexible schedule;Remote work o...  Very satisfied
#
#                                               JobSeek  \
# 34  I’m not actively looking, but I am open to new...
# 39  I’m not actively looking, but I am open to new...
# 55       I am not interested in new job opportunities
# 65  I’m not actively looking, but I am open to new...
# 84  I’m not actively looking, but I am open to new...
#
#                                LanguageDesireNextYear  \
# 34              HTML/CSS;JavaScript;Python;TypeScript
# 39                      C#;HTML/CSS;JavaScript;Python
# 55                                  Python;TypeScript
# 65  Bash/Shell/PowerShell;C;C#;C++;Julia;Python;Ru...
# 84                                   JavaScript;Swift
#
#                                    LanguageWorkedWith  MiscTechDesireNextYear  \
# 34                      HTML/CSS;Java;JavaScript;Ruby                 Node.js
# 39        C;C#;C++;HTML/CSS;JavaScript;PHP;Python;SQL  Unity 3D;Unreal Engine
# 55      HTML/CSS;JavaScript;PHP;Python;SQL;TypeScript  Unity 3D;Unreal Engine
# 65  Bash/Shell/PowerShell;C;C#;C++;HTML/CSS;Java;J...   Node.js;Torch/PyTorch
# 84  Bash/Shell/PowerShell;C#;Go;HTML/CSS;Java;Java...                 Node.js
#
#                                    MiscTechWorkedWith  \
# 34                               Node.js;React Native
# 39                        .NET;Unity 3D;Unreal Engine
# 55                                                NaN
# 65                                     Node.js;Pandas
# 84  .NET;.NET Core;Cordova;Node.js;React Native;Un...
#
#                          NEWCollabToolsDesireNextYear  \
# 34                                             Github
# 39  Jira;Github;Gitlab;Slack;Trello;Google Suite (...
# 55              Gitlab;Slack;Stack Overflow for Teams
# 65                                      Github;Gitlab
# 84                                                NaN
#
#                              NEWCollabToolsWorkedWith NEWDevOps NEWDevOpsImpt  \
# 34                                      Github;Trello       NaN           NaN
# 39  Confluence;Jira;Github;Gitlab;Slack;Trello;Goo...       NaN           NaN
# 55                Confluence;Jira;Github;Gitlab;Slack       Yes       Neutral
# 65                                      Github;Gitlab       NaN           NaN
# 84  Jira;Github;Slack;Microsoft Teams;Microsoft Az...  Not sure       Neutral
#
#              NEWEdImpt                                         NEWJobHunt  \
# 34                 NaN                                                NaN
# 39                 NaN                                                NaN
# 55  Somewhat important  Trouble with my direct manager;Trouble with le...
# 65                 NaN  Curious about other opportunities;Better compe...
# 84      Very important  Curious about other opportunities;Better compe...
#
#                                    NEWJobHuntResearch     NEWLearn  \
# 34                                                NaN  Once a year
# 39                                                NaN  Once a year
# 55  Company reviews from third party sites (e.g. G...  Once a year
# 65  Read company media, such as employee blogs or ...  Once a year
# 84  Company reviews from third party sites (e.g. G...  Once a year
#
#    NEWOffTopic NEWOnboardGood NEWOtherComms NEWOvertime  \
# 34         NaN            NaN           Yes         NaN
# 39    Not sure            NaN            No         NaN
# 55    Not sure             No            No       Never
# 65    Not sure            NaN            No         NaN
# 84    Not sure            Yes            No       Never
#
#                                   NEWPurchaseResearch      NEWPurpleLink  \
# 34  Visit developer communities like Stack Overflo...  Hello, old friend
# 39                                                NaN                NaN
# 55                                                NaN        Indifferent
# 65  Start a free trial;Ask developers I know/work ...  Hello, old friend
# 84  Start a free trial;Ask developers I know/work ...  Hello, old friend
#
#                                            NEWSOSites  \
# 34  Stack Overflow (public Q&A for anyone who code...
# 39  Stack Overflow (public Q&A for anyone who code...
# 55  Stack Overflow (public Q&A for anyone who code...
# 65   Stack Overflow (public Q&A for anyone who codes)
# 84   Stack Overflow (public Q&A for anyone who codes)
#
#                                              NEWStuck        OpSys  \
# 34  Visit Stack Overflow;Go for a walk or other ph...        MacOS
# 39                                                NaN      Windows
# 55  Play games;Call a coworker or friend;Visit Sta...        MacOS
# 65  Visit Stack Overflow;Go for a walk or other ph...  Linux-based
# 84  Call a coworker or friend;Visit Stack Overflow...      Windows
#
#                  OrgSize              PlatformDesireNextYear  \
# 34                   NaN                                 NaN
# 39                   NaN           Android;iOS;Linux;Windows
# 55  500 to 999 employees             Docker;Kubernetes;Linux
# 65                   NaN  Android;Arduino;Linux;Raspberry Pi
# 84                   NaN            Android;iOS;Raspberry Pi
#
#                              PlatformWorkedWith  \
# 34                      AWS;iOS;Linux;WordPress
# 39                    Android;iOS;Linux;Windows
# 55                                 Docker;Linux
# 65                                        Linux
# 84  Docker;iOS;Linux;MacOS;Raspberry Pi;Windows
#
#                      PurchaseWhat                Sexuality SOAccount  \
# 34                            NaN  Straight / Heterosexual       Yes
# 39                            NaN  Straight / Heterosexual       Yes
# 55  I have little or no influence  Straight / Heterosexual       Yes
# 65                            NaN                 Bisexual       Yes
# 84          I have some influence                 Bisexual       Yes
#
#              SOComm                                         SOPartFreq  \
# 34    Yes, somewhat                Less than once per month or monthly
# 39   No, not really  I have never participated in Q&A on Stack Over...
# 55  Yes, definitely                              Daily or almost daily
# 65          Neutral                               A few times per week
# 84          Neutral  I have never participated in Q&A on Stack Over...
#
#                         SOVisitFreq                  SurveyEase  \
# 34  A few times per month or weekly                        Easy
# 39  A few times per month or weekly                        Easy
# 55           Multiple times per day                        Easy
# 65            Daily or almost daily  Neither easy nor difficult
# 84             A few times per week                        Easy
#
#              SurveyLength Trans  \
# 34               Too long    No
# 39  Appropriate in length    No
# 55  Appropriate in length    No
# 65  Appropriate in length    No
# 84  Appropriate in length    No
#
#                                        UndergradMajor  \
# 34  Information systems, information technology, o...
# 39                                                NaN
# 55  A natural science (such as biology, chemistry,...
# 65  Computer science, computer engineering, or sof...
# 84                      Web development or web design
#
#                                WebframeDesireNextYear  \
# 34  Angular;Angular.js;Express;jQuery;React.js;Vue.js
# 39                                                NaN
# 55                                             Django
# 65                                                NaN
# 84    Angular;Angular.js;Django;Flask;jQuery;React.js
#
#                       WebframeWorkedWith  \
# 34                        Express;jQuery
# 39                                   NaN
# 55                               Symfony
# 65                         Django;jQuery
# 84  ASP.NET;ASP.NET Core;jQuery;React.js
#
#                                         WelcomeChange  WorkWeekHrs YearsCode  \
# 34            Just as welcome now as I felt last year          NaN         3
# 39            Just as welcome now as I felt last year          NaN         6
# 55            Just as welcome now as I felt last year         40.0         6
# 65  Not applicable - I did not use Stack Overflow ...          NaN        12
# 84            Just as welcome now as I felt last year         24.0         6
#
#    YearsCodePro
# 34          NaN
# 39          NaN
# 55            4
# 65          NaN
# 84            1

# %%
In_2020_Man.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
# 5           6                     I am a developer by profession       No
# 7           8                     I am a developer by profession      Yes
# 8           9                     I am a developer by profession       No
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp        Country  \
# 0   NaN         13  Monthly        NaN            NaN        Germany
# 4  31.0         16      NaN        NaN            NaN  United States
# 5   NaN         14      NaN        NaN            NaN        Germany
# 7  36.0         12   Yearly   116000.0       116000.0  United States
# 8  30.0         20      NaN        NaN            NaN        Tunisia
#
#            CurrencyDesc CurrencySymbol DatabaseDesireNextYear  \
# 0         European Euro            EUR   Microsoft SQL Server
# 4                   NaN            NaN       MySQL;PostgreSQL
# 5         European Euro            EUR                    NaN
# 7  United States dollar            USD                MongoDB
# 8  United States dollar            USD                    NaN
#
#                           DatabaseWorkedWith  \
# 0  Elasticsearch;Microsoft SQL Server;Oracle
# 4              MySQL;PostgreSQL;Redis;SQLite
# 5                                        NaN
# 7                        MariaDB;MySQL;Redis
# 8                                        NaN
#
#                                              DevType  \
# 0  Developer, desktop or enterprise applications;...
# 4                                                NaN
# 5    Designer;Developer, front-end;Developer, mobile
# 7  Developer, back-end;Developer, desktop or ente...
# 8                              Developer, full-stack
#
#                                              EdLevel  \
# 0    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5  Secondary school (e.g. American high school, G...
# 7       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 8                 Professional degree (JD, MD, etc.)
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 4                                 Employed full-time
# 5                                 Employed full-time
# 7                                 Employed full-time
# 8  Independent contractor, freelancer, or self-em...
#
#                       Ethnicity Gender  \
# 0  White or of European descent    Man
# 4  White or of European descent    Man
# 5  White or of European descent    Man
# 7  White or of European descent    Man
# 8                           NaN    Man
#
#                                           JobFactors                 JobSat  \
# 0  Languages, frameworks, and other technologies ...     Slightly satisfied
# 4                                                NaN                    NaN
# 5  Diversity of the company or organization;Langu...     Slightly satisfied
# 7  Remote work options;Opportunities for professi...  Slightly dissatisfied
# 8  Diversity of the company or organization;Remot...      Very dissatisfied
#
#                                              JobSeek  \
# 0       I am not interested in new job opportunities
# 4                                                NaN
# 5       I am not interested in new job opportunities
# 7  I’m not actively looking, but I am open to new...
# 8  I’m not actively looking, but I am open to new...
#
#      LanguageDesireNextYear        LanguageWorkedWith MiscTechDesireNextYear  \
# 0    C#;HTML/CSS;JavaScript    C#;HTML/CSS;JavaScript      .NET Core;Xamarin
# 4           Java;Ruby;Scala         HTML/CSS;Ruby;SQL           Ansible;Chef
# 5  HTML/CSS;Java;JavaScript  HTML/CSS;Java;JavaScript                    NaN
# 7                JavaScript                Python;SQL               Unity 3D
# 8               Python;Rust   HTML/CSS;JavaScript;PHP                    NaN
#
#   MiscTechWorkedWith            NEWCollabToolsDesireNextYear  \
# 0     .NET;.NET Core  Microsoft Teams;Microsoft Azure;Trello
# 4            Ansible   Github;Google Suite (Docs, Meet, etc)
# 5                NaN                            Github;Slack
# 7            Ansible                                     NaN
# 8                NaN                                     NaN
#
#                             NEWCollabToolsWorkedWith NEWDevOps  \
# 0       Confluence;Jira;Slack;Microsoft Azure;Trello        No
# 4  Confluence;Jira;Github;Slack;Google Suite (Doc...       NaN
# 5                     Confluence;Github;Slack;Trello  Not sure
# 7  Confluence;Jira;Github;Slack;Microsoft Teams;G...       Yes
# 8  Github;Slack;Trello;Google Suite (Docs, Meet, ...       NaN
#
#          NEWDevOpsImpt                           NEWEdImpt  \
# 0   Somewhat important                    Fairly important
# 4                  NaN                      Very important
# 5                  NaN                    Fairly important
# 7  Extremely important  Not at all important/not necessary
# 8                  NaN                      Very important
#
#                                           NEWJobHunt  \
# 0                                                NaN
# 4                                                NaN
# 5                                                NaN
# 7  Curious about other opportunities;Better compe...
# 8  Curious about other opportunities;Growth or le...
#
#                                   NEWJobHuntResearch     NEWLearn NEWOffTopic  \
# 0                                                NaN  Once a year    Not sure
# 4                                                NaN  Once a year          No
# 5                                                NaN  Once a year          No
# 7  Read company media, such as employee blogs or ...  Once a year    Not sure
# 8                                                NaN  Once a year          No
#
#   NEWOnboardGood NEWOtherComms  \
# 0            NaN            No
# 4            NaN           Yes
# 5             No            No
# 7            Yes            No
# 8            Yes            No
#
#                                          NEWOvertime  \
# 0                   Often: 1-2 days per week or more
# 4                                                NaN
# 5                                              Never
# 7  Occasionally: 1-2 days per quarter but less th...
# 8  Occasionally: 1-2 days per quarter but less th...
#
#                                  NEWPurchaseResearch      NEWPurpleLink  \
# 0  Start a free trial;Ask developers I know/work ...             Amused
# 4  Start a free trial;Ask developers I know/work ...  Hello, old friend
# 5  Ask developers I know/work with;Read ratings o...             Amused
# 7  Start a free trial;Ask developers I know/work ...  Hello, old friend
# 8                                 Start a free trial  Hello, old friend
#
#                                           NEWSOSites  \
# 0   Stack Overflow (public Q&A for anyone who codes)
# 4  Stack Overflow (public Q&A for anyone who code...
# 5  Stack Overflow (public Q&A for anyone who code...
# 7  Stack Overflow (public Q&A for anyone who code...
# 8  Stack Overflow (public Q&A for anyone who code...
#
#                                             NEWStuck        OpSys  \
# 0  Visit Stack Overflow;Go for a walk or other ph...      Windows
# 4  Call a coworker or friend;Visit Stack Overflow...      Windows
# 5  Play games;Visit Stack Overflow;Watch help / t...      Windows
# 7  Play games;Call a coworker or friend;Visit Sta...  Linux-based
# 8                                           Meditate      Windows
#
#                                              OrgSize  \
# 0                                   2 to 9 employees
# 4                                                NaN
# 5                                                NaN
# 7                                 20 to 99 employees
# 8  Just me - I am a freelancer, sole proprietor, ...
#
#                               PlatformDesireNextYear  \
# 0     Android;iOS;Kubernetes;Microsoft Azure;Windows
# 4  Docker;Google Cloud Platform;Heroku;Linux;Windows
# 5                                            Android
# 7                    iOS;Slack Apps and Integrations
# 8                                                NaN
#
#                PlatformWorkedWith           PurchaseWhat  \
# 0                         Windows                    NaN
# 4  AWS;Docker;Linux;MacOS;Windows                    NaN
# 5        Android;Docker;WordPress  I have some influence
# 7                          Docker  I have some influence
# 8                       WordPress                    NaN
#
#                  Sexuality SOAccount           SOComm  \
# 0  Straight / Heterosexual        No   No, not at all
# 4  Straight / Heterosexual       Yes    Yes, somewhat
# 5  Straight / Heterosexual       Yes    Yes, somewhat
# 7  Straight / Heterosexual       Yes   No, not really
# 8  Straight / Heterosexual       Yes  Yes, definitely
#
#                             SOPartFreq                      SOVisitFreq  \
# 0                                  NaN           Multiple times per day
# 4  Less than once per month or monthly  A few times per month or weekly
# 5      A few times per month or weekly             A few times per week
# 7  Less than once per month or monthly           Multiple times per day
# 8               Multiple times per day           Multiple times per day
#
#                    SurveyEase           SurveyLength Trans  \
# 0  Neither easy nor difficult  Appropriate in length    No
# 4                        Easy              Too short    No
# 5  Neither easy nor difficult  Appropriate in length   NaN
# 7                        Easy  Appropriate in length    No
# 8  Neither easy nor difficult  Appropriate in length    No
#
#                                       UndergradMajor  WebframeDesireNextYear  \
# 0  Computer science, computer engineering, or sof...            ASP.NET Core
# 4  Computer science, computer engineering, or sof...    Django;Ruby on Rails
# 5                                                NaN                React.js
# 7  Computer science, computer engineering, or sof...  Django;React.js;Vue.js
# 8  Computer science, computer engineering, or sof...              Angular.js
#
#      WebframeWorkedWith                            WelcomeChange  WorkWeekHrs  \
# 0  ASP.NET;ASP.NET Core  Just as welcome now as I felt last year         50.0
# 4         Ruby on Rails  Just as welcome now as I felt last year          NaN
# 5                   NaN                                      NaN          NaN
# 7                 Flask  Just as welcome now as I felt last year         39.0
# 8                jQuery  Just as welcome now as I felt last year         50.0
#
#   YearsCode YearsCodePro
# 0        36           27
# 4        15            8
# 5         6            4
# 7        17           13
# 8         6            4

# %%
# Preparing the data for men and women in 2020 for launguage worked in that year
worked_lang_man_2020 = split_lang_column(In_2020_Man, 'LanguageWorkedWith')
worked_lang_woman_2020 = split_lang_column(In_2020_Woman, 'LanguageWorkedWith')
list_worked_lang_man_2020 = disarray(worked_lang_man_2020)
list_worked_lang_woman_2020 = disarray(worked_lang_woman_2020)
dict_worked_languages_Man = group_list(list_worked_lang_man_2020, 'Man_2020')
dict_worked_languages_Woman = group_list(list_worked_lang_woman_2020, 'Woman_2020')

df_man = pd.DataFrame(dict_worked_languages_Man)
df_woman = pd.DataFrame(dict_worked_languages_Woman)
df_all_worked =df_man.append(df_woman)

# %%
# Function to subset the data for gender pay gap analysis in India
def prepare_data_india(df,column_needed,filter_gender,column_na,year):
    df_final = df[column_needed]
    df_final = df_final[df_final['Country']=='India']
    df_final = df_final[df_final['Gender'].isin(filter_gender)].dropna(axis=0,subset=[column_na])
    df_final['year']=year
    return df_final

# %%
# prepare the data and in order to align gender value form 2018 data with 2019 & 2020. we will use replace funtion
df_in_2020=prepare_data_india(df_2020,['Respondent','Gender','ConvertedComp','Country'],["Man","Woman"],'ConvertedComp','2020')
df_in_2019=prepare_data_india(df_2019,['Respondent','Gender','ConvertedComp','Country'],["Man","Woman"],'ConvertedComp','2019')
df_in_2018=prepare_data_india(df_2018,['Respondent','Gender','ConvertedSalary','Country'],["Male","Female"],'ConvertedSalary','2018')
df_in_2018["Gender"].replace({"Male": "Man", "Female": "Woman"}, inplace=True)
df_in_2018= df_in_2018.rename(columns = {'ConvertedSalary': 'ConvertedComp'}, inplace = False)

# %%
# prepare the final dataset by appending data from different years 

df_pay_final = df_in_2020.append(df_in_2019).append(df_in_2018)

# %% [markdown]
# # 4. Result evaluation
#
# ## Part 1 : Most popular languages in India across years?
#
# From our analysis, Java, Java script and SQL has been the most poplar language being used in India from 2018 to 2020. However, we can also notice the usage of python & C programming languages have been increasing on a year on year basis.

# %%
# Calculating the percentage for worked language
worked_languages['Percentage'] = pop_percentage(worked_languages, 'Year')

# %%
# Get the top 10 worked languages and filter the dataframe on them
top_10_worked_lang = worked_languages.sort_values(by=['Year','Percentage'], ascending=False).head(10)['Programming Language'].unique()
worked_lang_chart = worked_languages[worked_languages['Programming Language'].isin(top_10_worked_lang)]

# %%
# Figure 1 — Percentage of use of programming languages among all the cited programming 
# languages by the respondents.

plt.figure(figsize=(14,8))
sns.barplot(x = 'Percentage', 
            y = 'Programming Language',
            hue = 'Year',
            data = worked_lang_chart.sort_values(by=['Year','Percentage'], ascending=False))

plt.xlabel("Percentage", fontsize = 14)
plt.ylabel("Programming Languages", fontsize = 14)
plt.legend(fontsize='x-large', title_fontsize='40')
plt.title('Most common Programming Languages used in India', size = 16)
plt.show()

# %%
worked_lang_chart[worked_lang_chart['Programming Language']=='Python']
# Out:
#    Count Programming Language  Year  Percentage
# 1   2662               Python  2018    0.054614
# 2   2940               Python  2019    0.075769
# 2   2468               Python  2020    0.084975

# %% [markdown]
# Please note, as per the data provided, HTML and CSS were different options as per the survey in 2018, however, these two languages have been combined in the 2019 and 2020 survey.
#
# Python usage from 2018 to 2020 has increased significantly where in 2018, 5% of respondents were working on python and it has increased to 8% in 2020.
#
# ##  Part 2 : Which is the most lucrative programming languages people want to pursue in India?
#
# In this section, we will look into most desired language response.

# %%
# Calculating the percentage for wanted language
wanted_languages['Percentage'] = pop_percentage(wanted_languages, 'Year')

# %%
# Get the top 10 wanted languages and filter the dataframe on them
top_10_wanted_lang = wanted_languages.sort_values(by=['Year','Percentage'], ascending=False).head(10)['Programming Language'].unique()
wanted_lang_chart = wanted_languages[wanted_languages['Programming Language'].isin(top_10_worked_lang)]

# %%
# Figure 2 — Percentage of desire of programming languages among all the cited programming 
# languages by the respondents.

plt.figure(figsize=(14,8))
sns.barplot(x = 'Percentage', 
            y = 'Programming Language',
            hue = 'Year',
            data = wanted_lang_chart.sort_values(by=['Year','Percentage'], ascending=False))

plt.title('Most wanted Programming Languages used in India', size = 16)
plt.xlabel("Percentage", fontsize = 14)
plt.ylabel("Programming Languages", fontsize = 14)
plt.legend(fontsize='x-large', title_fontsize='40')
plt.show()

# %% [markdown]
# Python is being used on various platforms such as AWS, Zeppelin and Anaconda & it has over taken java script. People in the IT industry want to work on machine learning and python has been a lucrative option. It offers advantages over other languages at present and if we look into this historically, it has been duly noted by the survey respondents.
#
# # Part 3 : How do men and women differ in terms of choice of popular languages being used in India as per 2020 respondents?
#
# #Male and Female respondents

# %% [markdown]
# ## lets see the respondant ratio by Gender in 2020 from India

# %%
#We will only keep Men and Woen and will get rid off the other categories as we have low responses
In_2020=subset_country(df_2020, 'Country', 'India', ['Respondent','LanguageWorkedWith'])
plot_bar_chart(In_2020,"Gender","Stackoverflow Survey : India 2020")

# %%
In_2020_MF=In_2020[In_2020['Gender'].isin(["Man","Woman"])]
vals = (In_2020_MF['Gender'].value_counts()/In_2020_MF.shape[0])
vals
# Out:
# Man      0.931133
# Woman    0.068867
# Name: Gender, dtype: float64

# %% [markdown]
# As you could see, only 7% respondents were women and this is worrying.
#
# Being aware, that female respondents are low, I still want to do a comparison on the basis of percentage share.

# %%
# evaluating the percentage for each programming language : Men vs Women
df_all_worked['Percentage'] = pop_percentage(df_all_worked, 'Year')

# %%
# Get the top 10 languages
top_10_worked_2020 = df_all_worked.sort_values(by=['Year','Percentage'], ascending=False).head(10)['Programming Language'].unique()
worked_lang_chart_2020 = df_all_worked[df_all_worked['Programming Language'].isin(top_10_worked_lang)]

# %%
plt.figure(figsize=(14,8))
sns.barplot(y = 'Percentage', 
            x = 'Programming Language',
            
            hue = 'Year',
            data = worked_lang_chart_2020.sort_values(by=['Percentage'], ascending=False))

plt.ylabel("Percentage", fontsize = 14)
plt.xlabel("Programming Languages", fontsize = 14)
plt.legend(fontsize='x-large', title_fontsize='40')
plt.title('Most common Programming Languages used by Man and Woman in India', size = 16)
plt.show()

# %% [markdown]
# It is clearly evident that % share of female programmers using the top 5 languages are higher than male programmers. It would be interesting to monitor these results as female respondents increase in coming years.
#
# ## Part 4 : Finally, the salary comparison between Men and Women in India?
#
# We have seen that most of the 7% of female respondents have been working with the top 5 languages used in the Indian IT industry. Lets look into the average pay across years between women and men.

# %%
# calculating average salary for Men and women on year on year basis
df_pay_average = df_pay_final.groupby(['Gender','year']).mean().drop("Respondent",1)

# %%
df_pay_average
# Out:
#              ConvertedComp
# Gender year
# Man    2018   26055.368109
#        2019   28063.437297
#        2020   26428.845674
# Woman  2018   17216.187845
#        2019   12892.684729
#        2020   18173.524194

# %%
# creating index and sorting the data
df_in_graph = df_pay_average.reset_index()
df_in_graph['year'] = pd.to_numeric(df_in_graph['year'])
df_in_graph = df_in_graph.sort_values(by='year')
df_in_graph.set_index('year', inplace=True)

# %%
# ploting the gender pay line chart
df_in_graph.groupby('Gender')['ConvertedComp'].plot(legend=True)
plt.title("Average Salary Comparison between Men and Women in last 3 years");
plt.xlabel('Years')
plt.ylabel('Average Salary')
# Out:
# Text(0, 0.5, 'Average Salary')

# %% [markdown]
# This is surprising and you can see a wide gap in pay. For some reason, it is widest in 2019. In 2020, the average pay for the men has decreased in comparison to a sharp increase for women. Despite this, there is still a huge gap and the industry should take cognizance of it and should take decisive actions.

# %% [markdown]
# # Conclusion
#
#
# <ul>
# <li>Java has been the most popularly used language in India across years, however, there has been a significant increase in the usage of python.</li>
# <li>More and more people want to learn Python as it provides advantages in the Data Science Domain compared to other languages.</li>
# <li>The Indian IT industry has been dominated by Men, however, despite a low responses for women in survey, those who did respond are working with the top 5 languages.</li>
# <li>There is a huge gap in the average pay for men and women programmers and the industry should take decisive action to resolve it and promote more and more women in this area.</li>
# </ul>

# %% [markdown]
# ## WORDCLOUD CHAR FOR MY BLOG

# %%
df_wordcloud = pd.DataFrame(dict_wanted_languages_2020)

# %%
df_wordcloud.head()
# Out:
#    Count Programming Language  Year
# 0    521                 Ruby  2020
# 1    654                 Rust  2020
# 2   3697               Python  2020
# 3   1975                 Java  2020
# 4    655                    C  2020

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
text = df_wordcloud['Programming Language'].values
wordcloud = WordCloud(
    width = 3000,
    height = 2000,
    background_color = 'black',
    stopwords = STOPWORDS).generate(str(text))
fig = plt.figure(
    figsize = (40, 30),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()
